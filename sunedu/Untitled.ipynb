# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv('Licenciamiento_Institucional_5.csv', encoding='latin_1')
df
# Out:
#      CODIGO_ENTIDAD                                             NOMBRE  \
# 0                91              UNIVERSIDAD PRIVADA SAN CARLOS S.A.C.
# 1                16                  UNIVERSIDAD NACIONAL DE CAJAMARCA
# 2                67                     UNIVERSIDAD CONTINENTAL S.A.C.
# 3               118           UNIVERSIDAD PRIVADA JUAN PABLO II S.A.C.
# 4               104                  UNIVERSIDAD LE CORDON BLEU S.A.C.
# ..              ...                                                ...
# 138               2  UNIVERSIDAD NACIONAL DE SAN CRISTÓBAL DE HUAMANGA
# 139              78         UNIVERSIDAD PERUANA DE LAS AMÉRICAS S.A.C.
# 140              53       UNIVERSIDAD CATÓLICA LOS ÁNGELES DE CHIMBOTE
# 141               7             UNIVERSIDAD NACIONAL AGRARIA LA MOLINA
# 142              33    UNIVERSIDAD NACIONAL SANTIAGO ANTÚNEZ DE MAYOLO
#
#     TIPO_GESTION                         ESTADO_LICENCIAMIENTO  \
# ...

# %%
df_indexed = df.set_index('CODIGO_ENTIDAD')

# %%
df_lic_ = df.ESTADO_LICENCIAMIENTO.apply(lambda x: 'LICENCIADA' if x=='LICENCIA OTORGADA' else 'NO LICENCIADA')
df['ESTADO_LICENCIAMIENTO'] = df_lic_

# %%
sns.countplot(data=df, x='TIPO_GESTION', hue='ESTADO_LICENCIAMIENTO')
# Out:
# <AxesSubplot:xlabel='TIPO_GESTION', ylabel='count'>

# %%
sf = pd.read_csv('spotify.csv', encoding='utf-8')
sf.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 sf = pd.read_csv('spotify.csv', encoding='utf-8')
#       2 sf.head()
#
# File ~/proj/python-scripts/venv/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# !cat spotify.csv
# Out:
# ����/o�x����꺮L_zI���V�{��o?�+���~��
# ���c7�Νo�ӓ5E�_�E�d���8
# X%��U���j?�j98��lQ&�EU_K�YSm��ߦ֭
# �ZG[��WuL�K��*`�e�^m�jR)��~�zY�H͏�4��A,U�A
# �6��ڬ�?`%i�]�j���g����[D30,��r�	`�g����s��h��i�%��89I�(O��>���Aw ��d#�IḚ̖�h�������VuP^�촁vZu�@u���(�ABq��[���c��`�h5����밋u��%�
# �����Y��CxB��%]���Lx
# �!g��h�O���/�IE6�N5ڹ:ؠ��6�ϰa����BT��.ր+��?��8�G��Wa��Aٯz�W�s�J��4���Z}Qm��u46�&��k��
# �j��E�5\l�bW5G'��J����y,2Y|+��·��������j�e�ow����ò[]�r*:z*pު��^�_��/1����n%R�ٕ�Nt!lK[�]Z�G�E��f��7�b�Z>�SBpK#D`��������F��6��ߔEm��[h�aY�{j�	n�V��ɣ����T���/P@�e����^m���&ޒ
# p����.9aP}rV*o{4���E?�TTb
# ��L��P;�܎a�!ĥ�昤���wy�܌WK?������Ƥ����|z6���������D��
# �K�ȥ�;$TB)�.AW�~
# ;�9�'@r&�[���H,|/{�
# G���
# M�0q�
# �nq���͖U�19/��@P�(�-�ԟ���4��I�*٢��߂0�%��+i޷�N1�)Y5/}-S+��q���|���vɧ�� �M��l���&b*����i����"��_pA�����E���Q���%���v��������vs�ֻ��
# �@�64
# e.B��j��F�p�a!���`8`�,�����U��
# ����c���+�h}�*�R��^(������Q�$ON~Դ4������}ʊb.��]��xL���3��a��2���	���'�\M��O>4��J�
# Ǎe�{\����89��'l?E ���
# ...
