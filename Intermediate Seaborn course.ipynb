# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.catplot(kind='box', x='species',y='petal_length', data=df)

# %%
sns.violinplot(x='species',y='petal_width', data=df, alpha=.5)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.displot(data=df, x='sepal_width', rug=True, kind='kde', hue='species')

# %%
sns.relplot(kind='scatter', data=df, x='sepal_width', y='petal_width', hue='species')

# %%
sns.displot(data=df, x='sepal_width', y='sepal_length', kind='kde', hue='species')

# %%
sns.histplot(data=df, x='sepal_length', hue='species', multiple='stack')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.lmplot(data=df, x='sepal_width', y='petal_width', hue='species')

# %%
sns.jointplot(data=df, x='petal_width', y='sepal_width', hue='species')

# %%
sns.pairplot(data=df, hue='species')

# %% [markdown]
# Categorical data:
# -stripplot
# -swarmplot
# ->show rawly the data
#
# -boxplot
# -violinplot
# -lvplot
# ->show distribution
#
# -barplot
# -pointplot
# -countplot
# ->show features of the categorical data

# %%
sns.stripplot(data=df, x='sepal_length', y='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.swarmplot(data=df, x='sepal_length', y='species') #do not overlap
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.violinplot(data=df, x='sepal_length', y='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.boxenplot(data=df, x='sepal_length', y='species') #More eficient for large ammounts of data
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.barplot(data=df, x='sepal_length', y='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %% [markdown]
# ## Regression Plots

# %%
sns.regplot(data=df, x='sepal_length', y='sepal_width', marker='+', order=2)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.regplot(data=df, x='sepal_length', y='sepal_width', x_bins=20, order=3)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Matrix plots

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(pd.crosstab(df['sepal_width'], df['petal_width']))
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>

# %% [markdown]
# ## Facet grid, factorplot lmplot

# %%
g = sns.FacetGrid(df, col='species') #Returns something like a list that contains empty plots with data clasificada
g.map(sns.regplot, 'sepal_width', 'petal_width')#plotting functions, and paramaters

# %%
sns.factorplot(data=df, x='sepal_width', y='petal_width', col='species', kind='point') #This is going to be deleted soon, use code below
# Out:
# /home/andre/proj/python-scripts/venv/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.catplot(data=df, x='sepal_width', y='petal_width', col='species', kind='point')

# %%
sns.lmplot(data=df, x='sepal_width', y='petal_width', col='species')

# %% [markdown]
# ## PairGrid and pairplot

# %%
g = sns.PairGrid(df, vars=['sepal_width', 'sepal_length'])
g = g.map(sns.scatterplot)

# %%
g = sns.PairGrid(df, vars=['sepal_width', 'sepal_length'])
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
sns.pairplot(data=df, vars=['sepal_width', 'petal_width'], kind='reg')

# %% [markdown]
# ## JointGrid and jointplots

# %%
g = sns.JointGrid(data=df, x='sepal_width', y='sepal_length')
g.plot(sns.kdeplot, sns.histplot)

# %%
sns.jointplot(data=df, x='sepal_width', y='sepal_length', kind='kde').plot_marginals(sns.histplot)
